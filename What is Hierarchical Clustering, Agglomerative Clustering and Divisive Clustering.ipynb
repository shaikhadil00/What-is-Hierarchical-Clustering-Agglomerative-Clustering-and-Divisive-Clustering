# %% [markdown]
# # What is Hierarchical Clustering, Agglomerative  and Divisive Clustering?

# %% [markdown]
# ![Screenshot%202024-09-25%20074850.png](attachment:Screenshot%202024-09-25%20074850.png)

# %% [markdown]
# # here is example

# %% [markdown]
# ![Screenshot%202024-09-25%20075155.png](attachment:Screenshot%202024-09-25%20075155.png)

# %%
Top-Down Approch  = DIVISIVE Clustering

Bottom-UP Approch = AGGLOMERATIVE Clustering
